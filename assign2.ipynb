# %%
d={2:"dfbg",1:5,"serf":"w4rf"}
t=(5,3,7,8)
set={3,5,6,"e4y"}
print(d)
print(t)
print(set)
# Out:
# {2: 'dfbg', 1: 5, 'serf': 'w4rf'}
# (5, 3, 7, 8)
# {'e4y', 3, 5, 6}

# %%
def add(a,b):
    return a+b
def sub(a,b):
    return (a-b)
def mul(a,b):
    return (a*b)
def div(a,b):
    return (a//b)
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
print(add(a,b))
print(sub(a,b))
print(mul(a,b))
print(div(a,b))
# Out:
# 10
# 6
# 16
# 4

# %%
a=int(input("enter the first number:"))
b = int(str(a)[::-1])
if(a==b):
    print("the number is palindrome")
else:
    print("the number is not palindrome")
# Out:
# the number is not palindrome
