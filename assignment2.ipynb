# %%
student = {
    "name": "Lokesh",
    "age": 18,
    "course": "Python"
}

print(student)

print(student["name"])

student["age"] = 19

student["city"] = "Jaipur"

print(student)
# Out:
# {'name': 'Lokesh', 'age': 18, 'course': 'Python'}
# Lokesh
# {'name': 'Lokesh', 'age': 19, 'course': 'Python', 'city': 'Jaipur'}

# %%
numbers = (10, 20, 30, 40)

print(numbers)

print(numbers[1])

print(len(numbers))
# Out:
# (10, 20, 30, 40)
# 20
# 4

# %%
s = {1, 2, 3, 4, 4, 5}

print(s)

s.add(6)

s.remove(2)

print(s)
# Out:
# {1, 2, 3, 4, 5}
# {1, 3, 4, 5, 6}

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not possible"

# Taking input from user
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Enter first number:  58
# Enter second number:  40
# Addition = 98
# Subtraction = 18
# Multiplication = 2320
# Division = 1.45

# %%
num = int(input("Enter a number: "))

original = num
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

print("Reverse Number =", reverse)

if original == reverse:
    print("Palindrome Number")
else:
    print("Not a Palindrome Number")
# Out:
# Enter a number:  40
# Reverse Number = 4
# Not a Palindrome Number
